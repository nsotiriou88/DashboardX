# %%
# Author: Raghav RV <rvraghav93@gmail.com>
# License: BSD

import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

from sklearn.datasets import make_hastie_10_2
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier

print(__doc__)
# Out:
# Automatically created module for IPython interactive environment

# %%
X, y = make_hastie_10_2(n_samples=8000, random_state=42)

# The scorers can be either be one of the predefined metric strings or a scorer
# callable, like the one returned by make_scorer
scoring = {'AUC': 'roc_auc', 'Accuracy': make_scorer(accuracy_score)}

# Setting refit='AUC', refits an estimator on the whole dataset with the
# parameter setting that has the best cross-validated AUC score.
# That estimator is made available at ``gs.best_estimator_`` along with
# parameters like ``gs.best_score_``, ``gs.best_params_`` and
# ``gs.best_index_``
gs = GridSearchCV(DecisionTreeClassifier(random_state=42),
                  param_grid={'min_samples_split': range(2, 403, 10)},
                  scoring=scoring, refit='AUC', return_train_score=True)
gs.fit(X, y)
results = gs.cv_results_

# %%
pd.DataFrame(results)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.081536      0.002384         0.001695    2.365784e-04
# 1        0.081151      0.002404         0.001885    1.987698e-04
# 2        0.083541      0.006426         0.001897    2.047942e-04
# 3        0.079862      0.001749         0.001986    5.469885e-04
# 4        0.078963      0.001993         0.001581    1.856568e-04
# 5        0.078576      0.004414         0.001583    2.012333e-04
# 6        0.077178      0.002117         0.001780    2.381249e-04
# 7        0.077982      0.004053         0.001582    2.004348e-04
# 8        0.075896      0.004977         0.001669    2.341465e-04
# 9        0.075378      0.002520         0.001593    1.958153e-04
# 10       0.073016      0.001982         0.001681    2.358770e-04
# 11       0.072217      0.002404         0.001779    2.508630e-04
# 12       0.073014      0.002211         0.001592    2.035457e-04
# 13       0.071523      0.002573         0.001795    2.412200e-04
# 14       0.072422      0.002142         0.001679    2.280767e-04
# 15       0.070928      0.003364         0.001587    1.842242e-04
# 16       0.070421      0.002421         0.001800    2.250786e-04
# 17       0.072019      0.002830         0.001592    1.965813e-04
# 18       0.069643      0.002523         0.001882    1.966700e-04
# 19       0.069435      0.002216         0.001588    1.982153e-04
# 20       0.070935      0.004298         0.001680    3.830673e-04
# 21       0.068840      0.002476         0.001691    2.397581e-04
# 22       0.068244      0.002885         0.001686    2.330644e-04
# 23       0.067752      0.003241         0.001593    1.958091e-04
# 24       0.067651      0.002276         0.002087    9.624399e-04
# 25       0.068551      0.002743         0.001483    1.014666e-05
# 26       0.067463      0.002804         0.001580    2.025995e-04
# 27       0.067556      0.002537         0.001587    1.985552e-04
# 28       0.067468      0.002576         0.001575    1.897604e-04
# 29       0.067463      0.002502         0.001773    2.560615e-04
# 30       0.067654      0.002401         0.001587    1.985804e-04
# 31       0.068653      0.005340         0.001582    2.011050e-04
# 32       0.065779      0.002592         0.001688    2.439998e-04
# 33       0.068256      0.004236         0.001686    2.429850e-04
# 34       0.066474      0.002998         0.001770    2.418470e-04
# 35       0.066857      0.002447         0.001589    1.978816e-04
# 36       0.065862      0.002403         0.001577    2.035714e-04
# 37       0.066662      0.005122         0.001488    3.568323e-07
# 38       0.066071      0.002611         0.001588    1.987698e-04
# 39       0.067853      0.003569         0.001786    2.428484e-04
# 40       0.066172      0.003187         0.001682    2.362786e-04
#
#    param_min_samples_split                      params  split0_test_AUC  \
# 0                        2    {'min_samples_split': 2}         0.750681
# 1                       12   {'min_samples_split': 12}         0.794771
# 2                       22   {'min_samples_split': 22}         0.803303
# 3                       32   {'min_samples_split': 32}         0.814896
# 4                       42   {'min_samples_split': 42}         0.824982
# 5                       52   {'min_samples_split': 52}         0.833683
# 6                       62   {'min_samples_split': 62}         0.839375
# 7                       72   {'min_samples_split': 72}         0.842734
# 8                       82   {'min_samples_split': 82}         0.846684
# 9                       92   {'min_samples_split': 92}         0.850182
# 10                     102  {'min_samples_split': 102}         0.848035
# 11                     112  {'min_samples_split': 112}         0.848976
# 12                     122  {'min_samples_split': 122}         0.846058
# 13                     132  {'min_samples_split': 132}         0.845375
# 14                     142  {'min_samples_split': 142}         0.843001
# 15                     152  {'min_samples_split': 152}         0.841901
# 16                     162  {'min_samples_split': 162}         0.841643
# 17                     172  {'min_samples_split': 172}         0.841622
# 18                     182  {'min_samples_split': 182}         0.840022
# 19                     192  {'min_samples_split': 192}         0.840444
# 20                     202  {'min_samples_split': 202}         0.839842
# 21                     212  {'min_samples_split': 212}         0.838944
# 22                     222  {'min_samples_split': 222}         0.838345
# 23                     232  {'min_samples_split': 232}         0.831094
# 24                     242  {'min_samples_split': 242}         0.826347
# 25                     252  {'min_samples_split': 252}         0.826347
# 26                     262  {'min_samples_split': 262}         0.823588
# 27                     272  {'min_samples_split': 272}         0.825139
# 28                     282  {'min_samples_split': 282}         0.825139
# 29                     292  {'min_samples_split': 292}         0.821218
# 30                     302  {'min_samples_split': 302}         0.822465
# 31                     312  {'min_samples_split': 312}         0.821138
# 32                     322  {'min_samples_split': 322}         0.821138
# 33                     332  {'min_samples_split': 332}         0.815399
# 34                     342  {'min_samples_split': 342}         0.813164
# 35                     352  {'min_samples_split': 352}         0.813164
# 36                     362  {'min_samples_split': 362}         0.813164
# 37                     372  {'min_samples_split': 372}         0.813164
# 38                     382  {'min_samples_split': 382}         0.809236
# 39                     392  {'min_samples_split': 392}         0.809236
# 40                     402  {'min_samples_split': 402}         0.809236
#
#     split1_test_AUC  split2_test_AUC  split3_test_AUC  ...  \
# 0          0.781332         0.793312         0.777691  ...
# 1          0.833063         0.833786         0.823165  ...
# 2          0.841271         0.839880         0.834702  ...
# 3          0.843570         0.846161         0.849175  ...
# 4          0.849409         0.852856         0.854352  ...
# 5          0.850907         0.859609         0.861179  ...
# 6          0.855923         0.857674         0.864427  ...
# 7          0.859379         0.857135         0.867998  ...
# 24               0.784531               0.791250             0.793125
# 25               0.782344               0.787969             0.792031
# 26               0.782344               0.784687             0.790406
# 27               0.782344               0.784687             0.789469
# 28               0.782344               0.784687             0.788937
# 29               0.782344               0.781406             0.788281
# 30               0.782344               0.775937             0.787125
# 31               0.782344               0.775937             0.787125
# 32               0.782344               0.775937             0.786312
# 33               0.782344               0.775000             0.786125
# 34               0.782344               0.775000             0.786125
# 35               0.782344               0.775000             0.786125
# 36               0.782344               0.775000             0.786125
# 37               0.782344               0.775000             0.786125
# 38               0.782344               0.775000             0.786125
# 39               0.782344               0.775000             0.786125
# 40               0.782344               0.775000             0.786125
#
#     std_train_Accuracy
# 0             0.000000
# 1             0.002449
# 2             0.003021
# 3             0.004163
# 4             0.003474
# 5             0.002890
# 6             0.002019
# 7             0.003290
# 8             0.002306
# 9             0.005280
# 10            0.006180
# 11            0.005822
# 12            0.006185
# 13            0.005265
# 14            0.006572
# 15            0.007255
# 16            0.006546
# 17            0.007461
# 18            0.008810
# 19            0.008676
# 20            0.008903
# 21            0.008303
# 22            0.007105
# 23            0.006370
# 24            0.004888
# 25            0.005983
# 26            0.005905
# 27            0.005483
# 28            0.005519
# 29            0.006145
# 30            0.007587
# 31            0.007587
# 32            0.007753
# 33            0.008008
# 34            0.008008
# 35            0.008008
# 36            0.008008
# 37            0.008008
# 38            0.008008
# 39            0.008008
# 40            0.008008
#
# [41 rows x 36 columns]

# %%
plt.figure(figsize=(13, 13))
plt.title("GridSearchCV evaluating using multiple scorers simultaneously",
          fontsize=16)

plt.xlabel("min_samples_split")
plt.ylabel("Score")

ax = plt.gca()
ax.set_xlim(0, 402)
ax.set_ylim(0.73, 1)

# Get the regular numpy array from the MaskedArray
X_axis = np.array(results['param_min_samples_split'].data, dtype=float)

for scorer, color in zip(sorted(scoring), ['g', 'k']):
    for sample, style in (('train', '--'), ('test', '-')):
        sample_score_mean = results['mean_%s_%s' % (sample, scorer)]
        sample_score_std = results['std_%s_%s' % (sample, scorer)]
        ax.fill_between(X_axis, sample_score_mean - sample_score_std,
                        sample_score_mean + sample_score_std,
                        alpha=0.1 if sample == 'test' else 0, color=color)
        ax.plot(X_axis, sample_score_mean, style, color=color,
                alpha=1 if sample == 'test' else 0.7,
                label="%s (%s)" % (scorer, sample))

    best_index = np.nonzero(results['rank_test_%s' % scorer] == 1)[0][0]
    best_score = results['mean_test_%s' % scorer][best_index]

    # Plot a dotted vertical line at the best score for that scorer marked by x
    ax.plot([X_axis[best_index], ] * 2, [0, best_score],
            linestyle='-.', color=color, marker='x', markeredgewidth=3, ms=8)

    # Annotate the best score for that scorer
    ax.annotate("%0.2f" % best_score,
                (X_axis[best_index], best_score + 0.005))

plt.legend(loc="best")
plt.grid(False)
plt.show()
